# %% [markdown]
# ## Census Data Retrieval
# ---
# In this Jupyter notebook, we retrieve census data on every zip code and city in the United States.

# %% [markdown]
# ### Dependencies

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time 
from census import Census
from us import states
import sqlite3
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# Census API Key
c = Census("85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98", year=2015)

# %% [markdown]
# ### Retrieve Census Data

# %%
# Retrieve Census Data (Reference: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9b)
zip_census = c.acs5.get(( "B19013_001E",
                          "B19301_001E",
                          "B15003_002E",
                          "B15003_017E",
                          "B15003_018E",
                          "B15003_022E",
                          "B15003_021E",
                          "B15003_023E",
                          "B15003_024E",
                          "B15003_025E",
                          "B17001_002E",
                          "B23025_002E",
                          "B23025_005E",
                          "C24010_007E",
                          "C24010_043E",
                          "B01002_001E",
                          "B01002_002E",
                          "B01002_003E",
                          "B01003_001E",
                          "B25064_001E",
                          "B25077_001E",
                          "B25077_001E",
                          "B02001_002E",
                          "B02001_003E",
                          "B02001_004E",
                          "B02001_005E",
                          "B03001_003E"), {'for': 'zip code tabulation area:*'})

# Convert to DataFrame
zip_census = pd.DataFrame(zip_census)

# Column Reordering
zip_census = zip_census.rename(columns={"B19013_001E": "Household Income", 
                                      "B19301_001E": "Income Per Capita",
                                      "B15003_002E": "Education None",
                                      "B15003_017E": "Education High School",
                                      "B15003_018E": "Education GED",
                                      "B15003_022E": "Education Bachelors",
                                      "B15003_021E": "Education Associates",
                                      "B15003_023E": "Education Masters",
                                      "B15003_024E": "Education Professional",
                                      "B15003_025E": "Education Doctorate",
                                      "B17001_002E": "Poverty",
                                      "B23025_002E": "Employment Labor Force",
                                      "B23025_005E": "Employment Unemployed",
                                      "C24010_007E": "Employment Male Computer Engineering",
                                      "C24010_043E": "Employment Female Computer Engineering",
                                      "B01002_001E": "Median Age",
                                      "B01002_002E": "Median Male Age",
                                      "B01002_003E": "Median Female Age",
                                      "B01003_001E": "Population",
                                      "B25064_001E": "Median Gross Rent",
                                      "B25077_001E": "Median Home Value",
                                      "B02001_002E": "White Population",
                                      "B02001_003E": "Black Population",
                                      "B02001_004E": "Native American Population",
                                      "B02001_005E": "Asian Population",
                                      "B03001_003E": "Hispanic Population",
                                      "zip code tabulation area": "zipcode"})

# Visualize Data
zip_census.head()
# Out:
#    Median Age  Median Male Age  Median Female Age  Population  \
# 0        37.6             36.5               39.0     17982.0
# 1        39.5             38.6               40.3     40260.0
# 2        39.9             37.7               41.4     52408.0
# 3        40.8             41.0               40.3      6331.0
# 4        40.2             36.9               42.2     28328.0
#
#    White Population  Black Population  Native American Population  \
# 0           16956.0             102.0                        14.0
# 1           23144.0             693.0                         8.0
# 2           36177.0            2057.0                        76.0
# 3            4399.0             151.0                         0.0
# 4           17791.0             950.0                         0.0
#
#    Asian Population  Hispanic Population  Education None   ...     Poverty  \
# 0               0.0              17942.0           456.0   ...     10861.0
# 1              72.0              37681.0           955.0   ...     21720.0
# 2             655.0              50437.0          1014.0   ...     25459.0
# 3               0.0               6323.0           188.0   ...      4070.0
# 4              26.0              27999.0           377.0   ...     14005.0
#
#    Household Income  Income Per Capita  Employment Labor Force  \
# 0           10816.0             7453.0                  6162.0
# 1           16079.0             8474.0                 15289.0
# 2           16804.0            10179.0                 17058.0
# 3           12512.0             5863.0                  1679.0
# 4           17475.0             8452.0                  9542.0
#
#    Employment Unemployed  Median Gross Rent  Median Home Value  \
# 0                 2213.0              359.0           104500.0
# 1                 3807.0              395.0            90200.0
# 2                 3991.0              384.0           128400.0
# 3                  179.0              280.0           108500.0
# 4                 1495.0              424.0           113200.0
#
#    Employment Male Computer Engineering  \
# 0                                  60.0
# 1                                 211.0
# 2                                 362.0
# 3                                   9.0
# 4                                 126.0
#
#    Employment Female Computer Engineering  zipcode
# 0                                    21.0    00601
# 1                                    85.0    00602
# 2                                   150.0    00603
# 3                                     0.0    00606
# 4                                    45.0    00610
#
# [5 rows x 27 columns]

# %%
zip_census.columns
# Out:
# Index(['Median Age', 'Median Male Age', 'Median Female Age', 'Population',
#        'White Population', 'Black Population', 'Native American Population',
#        'Asian Population', 'Hispanic Population', 'Education None',
#        'Education High School', 'Education GED', 'Education Associates',
#        'Education Bachelors', 'Education Masters', 'Education Professional',
#        'Education Doctorate', 'Poverty', 'Household Income',
#        'Income Per Capita', 'Employment Labor Force', 'Employment Unemployed',
#        'Median Gross Rent', 'Median Home Value',
#        'Employment Male Computer Engineering',
#        'Employment Female Computer Engineering', 'zipcode'],
#       dtype='object')

# %%
zip_census.count()
# Out:
# Median Age                                32615
# Median Male Age                           32343
# Median Female Age                         32300
# Population                                33120
# White Population                          33120
# Black Population                          33120
# Native American Population                33120
# Asian Population                          33120
# Hispanic Population                       33120
# Education None                            33120
# Education High School                     33120
# Education GED                             33120
# Education Associates                      33120
# Education Bachelors                       33120
# Education Masters                         33120
# Education Professional                    33120
# Education Doctorate                       33120
# Poverty                                   33120
# Household Income                          31067
# Income Per Capita                         32542
# Employment Labor Force                    33120
# Employment Unemployed                     33120
# Median Gross Rent                         27431
# Median Home Value                         30793
# Employment Male Computer Engineering      33120
# Employment Female Computer Engineering    33120
# zipcode                                   33120
# dtype: int64

# %% [markdown]
# ### Retrieve Geocoding Data

# %%
zip_lat_lng = pd.read_excel("Raw/Latitude_Longitude_Zip.xlsx", converters={"zipcode": str})
zip_lat_lng.head()
# Out:
#   zipcode        lat        lng       city state     city-state
# 0   00601  18.180555 -66.749961   ADJUNTAS    PR   ADJUNTAS, PR
# 1   00602  18.361945 -67.175597     AGUADA    PR     AGUADA, PR
# 2   00603  18.455183 -67.119887  AGUADILLA    PR  AGUADILLA, PR
# 3   00606  18.158345 -66.932911    MARICAO    PR    MARICAO, PR
# 4   00610  18.295366 -67.125135     ANASCO    PR     ANASCO, PR

# %%
zip_lat_lng.count()
# Out:
# zipcode       33144
# lat           33144
# lng           33144
# city          33120
# state         33120
# city-state    33120
# dtype: int64

# %% [markdown]
# ### Merge Geocode Data with Census

# %%
zip_census_geocoded = zip_census.merge(zip_lat_lng, on="zipcode", how="left")
zip_census_geocoded.head()
# Out:
#    Median Age  Median Male Age  Median Female Age  Population  \
# 0        37.6             36.5               39.0     17982.0
# 1        39.5             38.6               40.3     40260.0
# 2        39.9             37.7               41.4     52408.0
# 3        40.8             41.0               40.3      6331.0
# 4        40.2             36.9               42.2     28328.0
#
#    White Population  Black Population  Native American Population  \
# 0           16956.0             102.0                        14.0
# 1           23144.0             693.0                         8.0
# 2           36177.0            2057.0                        76.0
# 3            4399.0             151.0                         0.0
# 4           17791.0             950.0                         0.0
#
#    Asian Population  Hispanic Population  Education None      ...        \
# 0               0.0              17942.0           456.0      ...
# 1              72.0              37681.0           955.0      ...
# 2             655.0              50437.0          1014.0      ...
# 3               0.0               6323.0           188.0      ...
# 4              26.0              27999.0           377.0      ...
#
#    Median Gross Rent  Median Home Value  Employment Male Computer Engineering  \
# 0              359.0           104500.0                                  60.0
# 1              395.0            90200.0                                 211.0
# 2              384.0           128400.0                                 362.0
# 3              280.0           108500.0                                   9.0
# 4              424.0           113200.0                                 126.0
#
#    Employment Female Computer Engineering  zipcode        lat        lng  \
# 0                                    21.0    00601  18.180555 -66.749961
# 1                                    85.0    00602  18.361945 -67.175597
# 2                                   150.0    00603  18.455183 -67.119887
# 3                                     0.0    00606  18.158345 -66.932911
# 4                                    45.0    00610  18.295366 -67.125135
#
#         city  state     city-state
# 0   ADJUNTAS     PR   ADJUNTAS, PR
# 1     AGUADA     PR     AGUADA, PR
# 2  AGUADILLA     PR  AGUADILLA, PR
# 3    MARICAO     PR    MARICAO, PR
# 4     ANASCO     PR     ANASCO, PR
#
# [5 rows x 32 columns]

# %%
zip_census_geocoded.count()
# Out:
# Median Age                                32615
# Median Male Age                           32343
# Median Female Age                         32300
# Population                                33120
# White Population                          33120
# Black Population                          33120
# Native American Population                33120
# Asian Population                          33120
# Hispanic Population                       33120
# Education None                            33120
# Education High School                     33120
# Education GED                             33120
# Education Associates                      33120
# Education Bachelors                       33120
# Education Masters                         33120
# Education Professional                    33120
# Education Doctorate                       33120
# Poverty                                   33120
# Household Income                          31067
# Income Per Capita                         32542
# Employment Labor Force                    33120
# Employment Unemployed                     33120
# Median Gross Rent                         27431
# Median Home Value                         30793
# Employment Male Computer Engineering      33120
# Employment Female Computer Engineering    33120
# zipcode                                   33120
# lat                                       33120
# lng                                       33120
# city                                      33120
# state                                     33120
# city-state                                33120
# dtype: int64

# %% [markdown]
# ### Add City, State Key

# %%
zip_census_geocoded["CityState"] = zip_census_geocoded["city"] + ", " + zip_census_geocoded["state"]
zip_census_geocoded["CityState"].head()
# Out:
# 0     ADJUNTAS, PR
# 1       AGUADA, PR
# 2    AGUADILLA, PR
# 3      MARICAO, PR
# 4       ANASCO, PR
# Name: CityState, dtype: object

# %%
zip_census_geocoded[zip_census_geocoded["CityState"] == "MIAMI, FL"][["Population", "zipcode"]].sum()
# Out:
# Population     1.820704e+06
# zipcode       3.310133e+279
# dtype: float64

# %% [markdown]
# ### Export CSV of Census Data (By Zip)

# %%
zip_census_geocoded.to_csv("Outputs/01-Zip_Census.csv", index=False)

# %% [markdown]
# ### Convert Columns to Numerics

# %%
zip_census_geocoded[['Median Age', 'Median Male Age', 'Median Female Age', 'Population',
       'White Population', 'Black Population', 'Native American Population',
       'Asian Population', 'Hispanic Population', 'Education None',
       'Education High School', 'Education GED', 'Education Associates',
       'Education Bachelors', 'Education Masters', 'Education Professional',
       'Education Doctorate', 'Poverty', 'Household Income',
       'Income Per Capita', 'Employment Labor Force', 'Employment Unemployed',
       'Median Gross Rent', 'Median Home Value',
       'Employment Male Computer Engineering',
       'Employment Female Computer Engineering', 'lat', 'lng']] = zip_census_geocoded[['Median Age', 'Median Male Age', 'Median Female Age', 'Population',
       'White Population', 'Black Population', 'Native American Population',
       'Asian Population', 'Hispanic Population', 'Education None',
       'Education High School', 'Education GED', 'Education Associates',
       'Education Bachelors', 'Education Masters', 'Education Professional',
       'Education Doctorate', 'Poverty', 'Household Income',
       'Income Per Capita', 'Employment Labor Force', 'Employment Unemployed',
       'Median Gross Rent', 'Median Home Value',
       'Employment Male Computer Engineering',
       'Employment Female Computer Engineering', 'lat', 'lng']].apply(pd.to_numeric)

# %%
# Check Data Types
zip_census_geocoded.dtypes
# Out:
# Median Age                                float64
# Median Male Age                           float64
# Median Female Age                         float64
# Population                                float64
# White Population                          float64
# Black Population                          float64
# Native American Population                float64
# Asian Population                          float64
# Hispanic Population                       float64
# Education None                            float64
# Education High School                     float64
# Education GED                             float64
# Education Associates                      float64
# Education Bachelors                       float64
# Education Masters                         float64
# Education Professional                    float64
# Education Doctorate                       float64
# Poverty                                   float64
# Household Income                          float64
# Income Per Capita                         float64
# Employment Labor Force                    float64
# Employment Unemployed                     float64
# Median Gross Rent                         float64
# Median Home Value                         float64
# Employment Male Computer Engineering      float64
# Employment Female Computer Engineering    float64
# zipcode                                    object
# lat                                       float64
# lng                                       float64
# city                                       object
# state                                      object
# city-state                                 object
# CityState                                  object
# dtype: object

# %% [markdown]
# ### Aggregate at City Level

# %%
# Group by city and calculate the sums 
zip_city_sums = zip_census_geocoded.groupby(["CityState", "city", "state"])[["Population", 
                                                                "White Population", 
                                                                "Black Population",
                                                                "Native American Population",
                                                                "Asian Population",
                                                                "Hispanic Population",
                                                                "Education None",
                                                                "Education High School",
                                                                "Education GED",
                                                               "Education Associates",
                                                               "Education Bachelors",
                                                               "Education Masters",
                                                               "Education Professional",
                                                               "Education Doctorate",
                                                               "Poverty",
                                                               "Employment Labor Force",
                                                               "Employment Unemployed",
                                                               "Employment Male Computer Engineering",
                                                               "Employment Female Computer Engineering"]].sum()

# Reset the index
zip_city_sums = zip_city_sums.reset_index()

# %%
# Group by city and calculate the averages 
zip_city_means = zip_census_geocoded.groupby(["city", "state"])[["Median Age",
                                                                 "Median Male Age",
                                                                 "Median Female Age",
                                                                 "Household Income",
                                                                 "Income Per Capita",
                                                                 "Median Gross Rent",
                                                                 "Median Home Value", "lat", "lng"
                                                                ]].mean()

# Reset the index
zip_city_means = zip_city_means.reset_index()

# %%
zip_city_sums.columns
# Out:
# Index(['CityState', 'city', 'state', 'Population', 'White Population',
#        'Black Population', 'Native American Population', 'Asian Population',
#        'Hispanic Population', 'Education None', 'Education High School',
#        'Education GED', 'Education Associates', 'Education Bachelors',
#        'Education Masters', 'Education Professional', 'Education Doctorate',
#        'Poverty', 'Employment Labor Force', 'Employment Unemployed',
#        'Employment Male Computer Engineering',
#        'Employment Female Computer Engineering'],
#       dtype='object')

# %%
zip_city_means.columns
# Out:
# Index(['city', 'state', 'Median Age', 'Median Male Age', 'Median Female Age',
#        'Household Income', 'Income Per Capita', 'Median Gross Rent',
#        'Median Home Value', 'lat', 'lng'],
#       dtype='object')

# %%
city_census_data = zip_city_sums.merge(zip_city_means, on=["city", "state"], how="left")

# %%
city_census_data.columns
# Out:
# Index(['CityState', 'city', 'state', 'Population', 'White Population',
#        'Black Population', 'Native American Population', 'Asian Population',
#        'Hispanic Population', 'Education None', 'Education High School',
#        'Education GED', 'Education Associates', 'Education Bachelors',
#        'Education Masters', 'Education Professional', 'Education Doctorate',
#        'Poverty', 'Employment Labor Force', 'Employment Unemployed',
#        'Employment Male Computer Engineering',
#        'Employment Female Computer Engineering', 'Median Age',
#        'Median Male Age', 'Median Female Age', 'Household Income',
#        'Income Per Capita', 'Median Gross Rent', 'Median Home Value', 'lat',
#        'lng'],
#       dtype='object')

# %% [markdown]
# ### Compare the Zip Stats and the City Stats

# %%
print(zip_census_geocoded["Population"].sum())
print(zip_census_geocoded["Employment Male Computer Engineering"].sum())
print(zip_census_geocoded["Household Income"].mean())
print(zip_census_geocoded["Median Age"].mean())
# Out:
# 320084105.0
# 5892832.0
# 53433.58473621528
# 41.90543308293794

# %%
print(city_census_data["Population"].sum())
print(city_census_data["Employment Male Computer Engineering"].sum())
print(city_census_data["Household Income"].mean())
print(city_census_data["Median Age"].mean())
# Out:
# 320084105.0
# 5892832.0
# 52893.2880117885
# 42.916076289730555

# %% [markdown]
# ### Export City Level CSV

# %%
city_census_data.to_csv("Outputs/02-City_Census.csv", index=False)

# %% [markdown]
# ### Export City and Zip Data to SQLite

# %%
conn = sqlite3.connect("Opportunity_Map.db")

# %%
city_census_data.to_sql("City_Census", conn, if_exists="replace", index=False)
# Out:
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py:1345: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
zip_census_geocoded.to_sql("Zip_Census", conn, if_exists="replace", index=False)
# Out:
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py:1345: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
pd.read_sql("select * from Zip_Census", conn)
# Out:
#        Median Age  Median Male Age  Median Female Age  Population  \
# 0            37.6             36.5               39.0     17982.0
# 1            39.5             38.6               40.3     40260.0
# 2            39.9             37.7               41.4     52408.0
# 3            40.8             41.0               40.3      6331.0
# 4            40.2             36.9               42.2     28328.0
# 5            39.9             38.1               41.6     64816.0
# 6            42.8             41.3               43.8     10707.0
# 33103                                     0.0    99832  58.015478 -136.166143
# 33104                                    34.0    99833  56.926675 -133.120372
# 33105                                    45.0    99835  57.000402 -135.076713
# 33106                                     1.0    99836  56.235218 -134.653499
# 33107                                     8.0    99840  59.575097 -135.335418
# 33108                                     4.0    99841  57.794300 -135.184384
# 33109                                    46.0    99901  55.540405 -131.105347
# 33110                                     0.0    99903  55.818431 -132.065800
# 33111                                     2.0    99918  55.916873 -132.695503
# 33112                                     0.0    99919  55.645594 -132.496820
# 33113                                     7.0    99921  55.407033 -132.766235
# 33114                                     0.0    99922  55.307528 -133.046815
# 33115                                     0.0    99923  56.002315 -130.041026
# 33116                                     4.0    99925  55.550204 -132.945933
# 33117                                     9.0    99926  55.138352 -131.470424
# 33118                                     0.0    99927  56.239062 -133.457924
# 33119                                    11.0    99929  56.370751 -131.693301
#
#                   city  state           city-state            CityState
# 0             ADJUNTAS     PR         ADJUNTAS, PR         ADJUNTAS, PR
# 1               AGUADA     PR           AGUADA, PR           AGUADA, PR
# 2            AGUADILLA     PR        AGUADILLA, PR        AGUADILLA, PR
# 3              MARICAO     PR          MARICAO, PR          MARICAO, PR
# 4               ANASCO     PR           ANASCO, PR           ANASCO, PR
# 5              ARECIBO     PR          ARECIBO, PR          ARECIBO, PR
# 6             BAJADERO     PR         BAJADERO, PR         BAJADERO, PR
# 7          BARCELONETA     PR      BARCELONETA, PR      BARCELONETA, PR
# 8             BOQUERON     PR         BOQUERON, PR         BOQUERON, PR
# 9            CABO ROJO     PR        CABO ROJO, PR        CABO ROJO, PR
# 10            PENUELAS     PR         PENUELAS, PR         PENUELAS, PR
# 11               CAMUY     PR            CAMUY, PR            CAMUY, PR
# 12            CASTANER     PR         CASTANER, PR         CASTANER, PR
# 13       SABANA GRANDE     PR    SABANA GRANDE, PR    SABANA GRANDE, PR
# 14              CIALES     PR           CIALES, PR           CIALES, PR
# 15              UTUADO     PR           UTUADO, PR           UTUADO, PR
# 16              DORADO     PR           DORADO, PR           DORADO, PR
# 17            ENSENADA     PR         ENSENADA, PR         ENSENADA, PR
# 18             FLORIDA     PR          FLORIDA, PR          FLORIDA, PR
# 19         GARROCHALES     PR      GARROCHALES, PR      GARROCHALES, PR
# 20             GUANICA     PR          GUANICA, PR          GUANICA, PR
# 21          GUAYANILLA     PR       GUAYANILLA, PR       GUAYANILLA, PR
# 22             HATILLO     PR          HATILLO, PR          HATILLO, PR
# 23         HORMIGUEROS     PR      HORMIGUEROS, PR      HORMIGUEROS, PR
# 24             ISABELA     PR          ISABELA, PR          ISABELA, PR
# 25              JAYUYA     PR           JAYUYA, PR           JAYUYA, PR
# 26               LAJAS     PR            LAJAS, PR            LAJAS, PR
# 27               LARES     PR            LARES, PR            LARES, PR
# 28          LAS MARIAS     PR       LAS MARIAS, PR       LAS MARIAS, PR
# 29              MANATI     PR           MANATI, PR           MANATI, PR
# ...                ...    ...                  ...                  ...
# 33090           AMBLER     AK           AMBLER, AK           AMBLER, AK
# 33091      CHALKYITSIK     AK      CHALKYITSIK, AK      CHALKYITSIK, AK
# 33092          NUIQSUT     AK          NUIQSUT, AK          NUIQSUT, AK
# 33093        FAIRBANKS     AK        FAIRBANKS, AK        FAIRBANKS, AK
# 33094          ATQASUK     AK          ATQASUK, AK          ATQASUK, AK
# 33095           JUNEAU     AK           JUNEAU, AK           JUNEAU, AK
# 33096           ANGOON     AK           ANGOON, AK           ANGOON, AK
# 33097          DOUGLAS     AK          DOUGLAS, AK          DOUGLAS, AK
# 33098       ELFIN COVE     AK       ELFIN COVE, AK       ELFIN COVE, AK
# 33099         GUSTAVUS     AK         GUSTAVUS, AK         GUSTAVUS, AK
# 33100           HAINES     AK           HAINES, AK           HAINES, AK
# 33101           HOONAH     AK           HOONAH, AK           HOONAH, AK
# 33102             KAKE     AK             KAKE, AK             KAKE, AK
# 33103          PELICAN     AK          PELICAN, AK          PELICAN, AK
# 33104       PETERSBURG     AK       PETERSBURG, AK       PETERSBURG, AK
# 33105            SITKA     AK            SITKA, AK            SITKA, AK
# 33106   PORT ALEXANDER     AK   PORT ALEXANDER, AK   PORT ALEXANDER, AK
# 33107          SKAGWAY     AK          SKAGWAY, AK          SKAGWAY, AK
# 33108  TENAKEE SPRINGS     AK  TENAKEE SPRINGS, AK  TENAKEE SPRINGS, AK
# 33109        KETCHIKAN     AK        KETCHIKAN, AK        KETCHIKAN, AK
# 33110     MEYERS CHUCK     AK     MEYERS CHUCK, AK     MEYERS CHUCK, AK
# 33111     COFFMAN COVE     AK     COFFMAN COVE, AK     COFFMAN COVE, AK
# 33112       THORNE BAY     AK       THORNE BAY, AK       THORNE BAY, AK
# 33113            CRAIG     AK            CRAIG, AK            CRAIG, AK
# 33114         HYDABURG     AK         HYDABURG, AK         HYDABURG, AK
# 33115            HYDER     AK            HYDER, AK            HYDER, AK
# 33116          KLAWOCK     AK          KLAWOCK, AK          KLAWOCK, AK
# 33117       METLAKATLA     AK       METLAKATLA, AK       METLAKATLA, AK
# 33118      POINT BAKER     AK      POINT BAKER, AK      POINT BAKER, AK
# 33119         WRANGELL     AK         WRANGELL, AK         WRANGELL, AK
#
# [33120 rows x 33 columns]

# %%
# Check Tables in SQLite
cur = conn.cursor() 
res = cur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
for name in res:
    print(name[0])
# Out:
# City_Census
# Zip_Census

# %% [markdown]
# ### Export to Cloud SQL

# %%
engine = create_engine('mysql+mysqldb://trilogy:test@35.227.28.228/mapping_data?unix_socket=/cloudsql/sql-projects:us-east1:opportunity-db')
conn = engine.connect()

city_census.to_sql("City_Census", conn, if_exists="replace", index=False)
zip_census.to_sql("Zip_Instances", conn, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-9c976104e062> in <module>()
#       2 conn = engine.connect()
#       3
# ----> 4 city_census.to_sql("City_Census", conn, if_exists="replace", index=False)
#       5 zip_census.to_sql("Zip_Instances", conn, if_exists="replace", index=False)
#
# NameError: name 'city_census' is not defined
