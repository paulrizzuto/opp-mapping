# %% [markdown]
# ## Closest University
# ---
# In this Jupyter notebook, we associate each city with the single nearest Trilogy campus using Google's distance matrix, and then Vincenty's distance formula.

# %% [markdown]
# If time column has a value, then pick shortest time, otherwise default to vincenty distance value in column ["Distance"]

# %% [markdown]
# ### Dependencies

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time 
import sqlite3
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ### Read the City Pair Combinations

# %%
conn = sqlite3.connect("Opportunity_Map.db")
distance_values = pd.read_sql("select * from FullDistances", conn)
distance_values.head()
# Out:
#    Asian Population  Black Population        City   City Lat   City Lng  \
# 0               0.0              53.0  CARRSVILLE  36.737390 -76.840511
# 1               0.0              53.0  CARRSVILLE  36.737390 -76.840511
# 2               0.0              53.0  CARRSVILLE  36.737390 -76.840511
# 3               0.0              53.0  CARRSVILLE  36.737390 -76.840511
# 4               0.0             613.0      CARSON  37.016961 -77.395057
#
#         CityState    Distance Distance_Text  Education Associates  \
# 0  CARRSVILLE, VA   65.400534       79.1 mi                 157.0
# 1  CARRSVILLE, VA  135.829465        176 mi                 157.0
# 2  CARRSVILLE, VA   65.400534       79.1 mi                 157.0
# 3  CARRSVILLE, VA  149.564762        185 mi                 157.0
# 4      CARSON, VA   36.830103       41.3 mi                 109.0
#
#    Education Bachelors       ...         Poverty  State     Time  \
# 0                113.0       ...            93.0     VA   5665.0
# 1                113.0       ...            93.0     VA  10258.0
# 2                113.0       ...            93.0     VA   5665.0
# 3                113.0       ...            93.0     VA  11045.0
# 4                 91.0       ...            20.0     VA   2610.0
#
#          Time_Text    Uni Lat    Uni Lng  University    Uni CityState  \
# 0   1 hour 34 mins  37.548987 -77.453429          UR     RICHMOND, VA
# 1  2 hours 51 mins  35.904912 -79.046913         UNC  CHAPEL HILL, NC
# 2   1 hour 34 mins  37.548987 -77.453429          UR     RICHMOND, VA
# 3   3 hours 4 mins  38.899715 -77.048599          GW   WASHINGTON, DC
# 4          44 mins  37.548987 -77.453429          UR     RICHMOND, VA
#
#    White Population  Physical_Campus
# 0            1549.0            FALSE
# 1            1549.0            FALSE
# 2            1549.0            FALSE
# 3            1549.0            FALSE
# 4             680.0            FALSE
#
# [5 rows x 41 columns]

# %%
distance_values.dtypes
# Out:
# Asian Population                          float64
# Black Population                          float64
# City                                       object
# City Lat                                  float64
# City Lng                                  float64
# CityState                                  object
# Distance                                  float64
# Distance_Text                              object
# Education Associates                      float64
# Education Bachelors                       float64
# Education Doctorate                       float64
# Education GED                             float64
# Education High School                     float64
# Education Masters                         float64
# Education None                            float64
# Education Professional                    float64
# Employment Female Computer Engineering    float64
# Employment Labor Force                    float64
# Employment Male Computer Engineering      float64
# Employment Unemployed                     float64
# Google_URL                                 object
# Hispanic Population                       float64
# Household Income                          float64
# Income Per Capita                         float64
# Median Age                                float64
# Median Female Age                         float64
# Median Gross Rent                         float64
# Median Home Value                         float64
# Median Male Age                           float64
# Native American Population                float64
# Population                                float64
# Poverty                                   float64
# State                                      object
# Time                                      float64
# Time_Text                                  object
# Uni Lat                                   float64
# Uni Lng                                   float64
# University                                 object
# Uni CityState                              object
# White Population                          float64
# Physical_Campus                            object
# dtype: object

# %%
distance_values[distance_values["CityState"] == "HOUSTON, TX"]
# Out:
#       Asian Population  Black Population     City   City Lat   City Lng  \
# 9845          230549.0          684416.0  HOUSTON  29.775734 -95.414548
# 9846          230549.0          684416.0  HOUSTON  29.775734 -95.414548
# 9847          230549.0          684416.0  HOUSTON  29.775734 -95.414548
#
#         CityState    Distance Distance_Text  Education Associates  \
# 9845  HOUSTON, TX    5.801359        8.9 mi              100014.0
# 9846  HOUSTON, TX  143.373805        162 mi              100014.0
# 9847  HOUSTON, TX  186.906597        193 mi              100014.0
#
#       Education Bachelors       ...          Poverty  State     Time  \
# 9845             349920.0       ...         633609.0     TX   1147.0
# 9846             349920.0       ...         633609.0     TX   9329.0
# 9847             349920.0       ...         633609.0     TX  10612.0
#
#             Time_Text    Uni Lat    Uni Lng  University    Uni CityState  \
# 9845          19 mins  29.719949 -95.342233          UT      HOUSTON, TX
# 9846  2 hours 35 mins  30.284918 -97.734057          UT       AUSTIN, TX
# 9847  2 hours 57 mins  29.424100 -98.493600        UTSA  SAN ANTONIO, TX
#
#       White Population  Physical_Campus
# 9845         1775897.0             TRUE
# 9846         1775897.0            FALSE
# 9847         1775897.0            FALSE
#
# [3 rows x 41 columns]

# %%
distance_values[distance_values["CityState"] == "ABBOTT, TX"]
# Out:
#       Asian Population  Black Population    City   City Lat  City Lng  \
# 9142               0.0               9.0  ABBOTT  31.881728 -97.08541
# 9143               0.0               9.0  ABBOTT  31.881728 -97.08541
# 9144               0.0               9.0  ABBOTT  31.881728 -97.08541
# 9145               0.0               9.0  ABBOTT  31.881728 -97.08541
#
#        CityState    Distance Distance_Text  Education Associates  \
# 9142  ABBOTT, TX  181.440631        208 mi                  90.0
# 9143  ABBOTT, TX   68.416138       80.3 mi                  90.0
# 9144  ABBOTT, TX  116.535657        124 mi                  90.0
# 9145  ABBOTT, TX  188.928462        204 mi                  90.0
#
#       Education Bachelors       ...         Poverty  State     Time  \
# 9142                120.0       ...           109.0     TX  11491.0
# 9143                120.0       ...           109.0     TX   4534.0
# 9144                120.0       ...           109.0     TX   6637.0
# 9145                120.0       ...           109.0     TX  10994.0
#
#             Time_Text    Uni Lat    Uni Lng  University    Uni CityState  \
# 9142  3 hours 12 mins  29.719949 -95.342233          UT      HOUSTON, TX
# 9143   1 hour 16 mins  32.841218 -96.784518         SMU       DALLAS, TX
# 9144   1 hour 51 mins  30.284918 -97.734057          UT       AUSTIN, TX
# 9145   3 hours 3 mins  29.424100 -98.493600        UTSA  SAN ANTONIO, TX
#
#       White Population  Physical_Campus
# 9142             985.0            FALSE
# 9143             985.0            FALSE
# 9144             985.0            FALSE
# 9145             985.0            FALSE
#
# [4 rows x 41 columns]

# %%
test = distance_values[distance_values["Time"].isnull()]

# %%
test.head()
# Out:
#       Asian Population  Black Population        City   City Lat   City Lng  \
# 1087               8.0             667.0   MC KENNEY  36.989430 -77.720290
# 1732              63.0            5226.0  SMITHFIELD  37.001261 -76.655932
# 1883               0.0               0.0     TANGIER  37.829055 -75.984124
# 1884               0.0               0.0     TANGIER  37.829055 -75.984124
# 1885               0.0               0.0     TANGIER  37.829055 -75.984124
#
#            CityState    Distance Distance_Text  Education Associates  \
# 1087   MC KENNEY, VA  105.133375          None                 158.0
# 1732  SMITHFIELD, VA   57.950293          None                1036.0
# 1883     TANGIER, VA   82.810104          None                  10.0
# 1884     TANGIER, VA   82.810104          None                  10.0
# 1885     TANGIER, VA   93.780761          None                  10.0
#
#       Education Bachelors       ...         Poverty  State  Time  Time_Text  \
# 1087                173.0       ...           401.0     VA   NaN       None
# 1732               2281.0       ...          2434.0     VA   NaN       None
# 1883                 24.0       ...            76.0     VA   NaN       None
# 1884                 24.0       ...            76.0     VA   NaN       None
# 1885                 24.0       ...            76.0     VA   NaN       None
#
#         Uni Lat    Uni Lng  University    Uni CityState  White Population  \
# 1087  35.904912 -79.046913         UNC  CHAPEL HILL, NC            1559.0
# 1732  37.548987 -77.453429          UR     RICHMOND, VA           11609.0
# 1883  37.548987 -77.453429          UR     RICHMOND, VA             487.0
# 1884  37.548987 -77.453429          UR     RICHMOND, VA             487.0
# 1885  38.899715 -77.048599          GW   WASHINGTON, DC             487.0
#
#       Physical_Campus
# 1087            FALSE
# 1732            FALSE
# 1883            FALSE
# 1884            FALSE
# 1885            FALSE
#
# [5 rows x 41 columns]

# %%
test_2 = test.loc[test.groupby("CityState")["Distance"].idxmin()]

# %%
test_2.head()
# Out:
#        Asian Population  Black Population           City   City Lat  \
# 63043               0.0               0.0      ABBYVILLE  38.006359
# 68253             708.0             541.0       ABERDEEN  45.482335
# 48927               5.0              53.0      ABERNATHY  33.857882
# 53744               0.0               0.0        ABIQUIU  36.282896
# 52540              22.0             381.0  ABITA SPRINGS  30.484687
#
#          City Lng          CityState    Distance Distance_Text  \
# 63043  -98.206324      ABBYVILLE, KS  208.322033          None
# 68253  -98.532540       ABERDEEN, SD  260.911653          None
# 48927 -101.881538      ABERNATHY, TX  302.981336          None
# 53744 -106.411988        ABIQUIU, NM  247.078038          None
# 52540  -89.953028  ABITA SPRINGS, LA  327.007194          None
#
#        Education Associates  Education Bachelors       ...         Poverty  \
# 63043                  18.0                 10.0       ...            26.0
# 68253                2120.0               4344.0       ...          3242.0
# 48927                 101.0                214.0       ...           695.0
# 53744                   0.0                142.0       ...            78.0
# 52540                 188.0               1144.0       ...           816.0
#
#        State  Time  Time_Text    Uni Lat     Uni Lng  University  \
# 63043     KS   NaN       None  39.114100  -94.627500          KU
# 68253     SD   NaN       None  44.975354  -93.233074        MINN
# 48927     TX   NaN       None  32.841218  -96.784518         SMU
# 53744     NM   NaN       None  39.676617 -104.961896          DU
# 52540     LA   NaN       None  29.719949  -95.342233          UT
#
#          Uni CityState  White Population  Physical_Campus
# 63043  KANSAS CITY, KS             330.0            FALSE
# 68253  MINNEAPOLIS, MN           28656.0            FALSE
# 48927       DALLAS, TX            3452.0            FALSE
# 53744       DENVER, CO             524.0            FALSE
# 52540      HOUSTON, TX            7301.0            FALSE
#
# [5 rows x 41 columns]

# %%
test_2["CityState"].nunique()
# Out:
# 5927

# %% [markdown]
# ### Identify the Single Closest University for Each City

# %%
closest_location_google = distance_values[distance_values["Time"].notnull()].loc[distance_values.groupby("CityState")["Time"].idxmin()][["CityState", "University", "Distance"]]

# %%
#closest_location = crow_distances.loc[crow_distances.groupby("CityState")["crow_distance"].idxmin()][["CityState", "University", "crow_distance"]]

# %%
closest_location_google_pd = pd.DataFrame(closest_location_google)
closest_location_google_pd.head(10)
# Out:
#                CityState University    Distance
# 14746.0   AARONSBURG, PA       PENN  140.339859
# 42505.0    ABBEVILLE, AL      GTECH  157.537626
# 27582.0    ABBEVILLE, GA      GTECH  138.382298
# 10872.0    ABBEVILLE, LA         UT  189.538012
# 37355.0    ABBEVILLE, MS       VAND  187.693841
# 6132.0     ABBEVILLE, SC      GTECH  116.574634
# 19110.0        ABBOT, ME        UNH  158.938804
# 32687.0   ABBOTSFORD, WI       MINN  144.634102
# 9143.0        ABBOTT, TX        SMU   68.416138
# 14749.0  ABBOTTSTOWN, PA       PENN   94.939740

# %%
closest_location_google_pd.nunique()
# Out:
# CityState     21355
# University       35
# Distance      21355
# dtype: int64

# %%
vincentys_one = distance_values[distance_values["Time"].isnull()]

# %%
closest_location_vincentys = vincentys_one.loc[vincentys_one.groupby("CityState")["Distance"].idxmin()][["CityState", "University", "Distance"]]

# %%
closest_location_vincentys_pd = pd.DataFrame(closest_location_vincentys)
closest_location_vincentys_pd.head(10)
# Out:
#                CityState University    Distance
# 63043      ABBYVILLE, KS         KU  208.322033
# 68253       ABERDEEN, SD       MINN  260.911653
# 48927      ABERNATHY, TX        SMU  302.981336
# 53744        ABIQUIU, NM         DU  247.078038
# 52540  ABITA SPRINGS, LA         UT  327.007194
# 67892       ABSARAKA, ND       MINN  243.281935
# 64947      ABSAROKEE, MT       UTAH  348.736084
# 48930        ACKERLY, TX         UT  281.986828
# 68556       ACKERMAN, MS       VAND  235.433623
# 52544           ACME, LA         UT  239.030077

# %%
frames = [closest_location_google_pd, closest_location_vincentys_pd]
closest_location_pd = pd.concat(frames, join='outer')

# %%
closest_location_pd.head()
# Out:
#               CityState University    Distance
# 14746.0  AARONSBURG, PA       PENN  140.339859
# 42505.0   ABBEVILLE, AL      GTECH  157.537626
# 27582.0   ABBEVILLE, GA      GTECH  138.382298
# 10872.0   ABBEVILLE, LA         UT  189.538012
# 37355.0   ABBEVILLE, MS       VAND  187.693841

# %%
closest_location_pd.count()
# Out:
# CityState     27282
# University    27282
# Distance      27282
# dtype: int64

# %%
closest_location_pd
# Out:
#                               CityState University    Distance
#  14746.0                 AARONSBURG, PA       PENN  140.339859
#  42505.0                  ABBEVILLE, AL      GTECH  157.537626
#  27582.0                  ABBEVILLE, GA      GTECH  138.382298
#  10872.0                  ABBEVILLE, LA         UT  189.538012
#  37355.0                  ABBEVILLE, MS       VAND  187.693841
#  6132.0                   ABBEVILLE, SC      GTECH  116.574634
#  19110.0                      ABBOT, ME        UNH  158.938804
#  32687.0                 ABBOTSFORD, WI       MINN  144.634102
#  9143.0                      ABBOTT, TX        SMU   68.416138
#  14749.0                ABBOTTSTOWN, PA       PENN   94.939740
# NaN                                 NaN        NaN         NaN
#  2168.0                       ABELL, MD         GW   47.038451
#  32624.0                ABERCROMBIE, ND       MINN  196.867734
#  2172.0     ABERDEEN PROVING GROUND, MD       PENN   59.949207
#  46152.0                   ABERDEEN, ID       UTAH  164.420299
#  2175.0                    ABERDEEN, MD       PENN   62.037623
#  37356.0                   ABERDEEN, MS       VAND  187.510012
#  11293.0                   ABERDEEN, NC        UNC   58.466696
#  33911.0                   ABERDEEN, OH        OSU   98.211065
# NaN                                 NaN        NaN         NaN
#  7016.0                    ABERDEEN, WA         UW   74.769063
# NaN                                 NaN        NaN         NaN
#  42615.0                       ABIE, NE         KU  196.496571
#  31468.0                    ABILENE, KS         KU  139.847089
#  28362.0                    ABILENE, TX        SMU  176.084188
#  43079.0                   ABINGDON, IL         NU  165.912617
#  2177.0                    ABINGDON, MD         GW   56.273476
#  12588.0                   ABINGDON, VA       UNCH  119.694981
#  19470.0                   ABINGTON, MA       HARV   17.633752
#  31782.0                   ABINGTON, PA       PENN   12.511147
# ...                                 ...        ...         ...
#  57607.0                       YALE, OK        SMU  225.397560
#  68554.0                       YALE, SD       MINN  237.094242
#  68555.0                    YANKTON, SD       MINN  253.720683
#  55862.0                    YATAHEY, NM         UA  243.537977
#  68877.0                 YAZOO CITY, MS       VAND  310.992102
#  62619.0                   YEADDISS, KY        OSU  203.283000
#  62914.0              YELLOW JACKET, CO         DU  254.580667
#  69927.0                YELLOW PINE, ID       UTAH  350.400951
#  64945.0  YELLOWSTONE NATIONAL PARK, WY       UTAH  269.844936
#  52536.0                  YELLVILLE, AR      WASHU  210.775529
#  69168.0                  YERINGTON, NV       UTAH  410.557496
#  55867.0                       YESO, NM         DU  359.709476
#  48895.0                       YORK, AL      GTECH  238.356659
#  68248.0                       YORK, ND       MINN  380.015808
#  61378.0                   YORKTOWN, IA      WASHU  295.585011
#  67671.0                 YOUNGSTOWN, FL        UCF  246.792655
#  53736.0                YOUNGSVILLE, LA         UT  201.368454
#  55875.0                YOUNGSVILLE, NM         DU  256.902545
#  68249.0                  YPSILANTI, ND       MINN  284.664216
#  57892.0                      YREKA, CA        UCD  227.048846
#  53740.0                    ZACHARY, LA         UT  258.678506
#  68250.0                       ZAHL, ND       MINN  556.759394
#  68251.0                        ZAP, ND       MINN  446.983550
#  68252.0                    ZEELAND, ND       MINN  325.871961
#  59611.0                    ZEIGLER, IL         NU  298.018446
#  63664.0                      ZENDA, KS         KU  231.513738
#  69172.0                ZEPHYR COVE, NV       UTAH  446.048028
#  65923.0                    ZORTMAN, MT       UTAH  508.479655
#  55881.0                       ZUNI, NM         UA  216.876876
#  65926.0                     ZURICH, MT       UTAH  562.458753
#
# [33165 rows x 3 columns]

# %%
closest_location_pd = closest_location_pd[closest_location_pd["CityState"].notnull()].reset_index()

# %%
closest_location_pd = closest_location_pd[["CityState", "University", "Distance"]]

# %%
closest_location_pd.count()
# Out:
# CityState     27282
# University    27282
# Distance      27282
# dtype: int64

# %%
closest_location_pd["Closest"] = True

# %%
closest_location_pd.count()
# Out:
# CityState     27282
# University    27282
# Distance      27282
# Closest       27282
# dtype: int64

# %%
distance_values.count()
# Out:
# Asian Population                          70093
# Black Population                          70093
# City                                      70093
# City Lat                                  70093
# City Lng                                  70093
# CityState                                 70093
# Distance                                  70093
# Distance_Text                             47801
# Education Associates                      70093
# Education Bachelors                       70093
# Education Doctorate                       70093
# Education GED                             70093
# Education High School                     70093
# Education Masters                         70093
# Education None                            70093
# Education Professional                    70093
# Employment Female Computer Engineering    70093
# Employment Labor Force                    70093
# Employment Male Computer Engineering      70093
# Employment Unemployed                     70093
# Google_URL                                48000
# Hispanic Population                       70093
# Household Income                          65698
# Income Per Capita                         69022
# Median Age                                69202
# Median Female Age                         68462
# Median Gross Rent                         56505
# Median Home Value                         65273
# Median Male Age                           68477
# Native American Population                70093
# Population                                70093
# Poverty                                   70093
# State                                     70093
# Time                                      47801
# Time_Text                                 47801
# Uni Lat                                   70093
# Uni Lng                                   70093
# University                                70093
# Uni CityState                             70093
# White Population                          70093
# Physical_Campus                           70093
# dtype: int64

# %%
closest_location_pd.dtypes
# Out:
# CityState      object
# University     object
# Distance      float64
# Closest          bool
# dtype: object

# %%
distance_values.dtypes
# Out:
# Asian Population                          float64
# Black Population                          float64
# City                                       object
# City Lat                                  float64
# City Lng                                  float64
# CityState                                  object
# Distance                                  float64
# Distance_Text                              object
# Education Associates                      float64
# Education Bachelors                       float64
# Education Doctorate                       float64
# Education GED                             float64
# Education High School                     float64
# Education Masters                         float64
# Education None                            float64
# Education Professional                    float64
# Employment Female Computer Engineering    float64
# Employment Labor Force                    float64
# Employment Male Computer Engineering      float64
# Employment Unemployed                     float64
# Google_URL                                 object
# Hispanic Population                       float64
# Household Income                          float64
# Income Per Capita                         float64
# Median Age                                float64
# Median Female Age                         float64
# Median Gross Rent                         float64
# Median Home Value                         float64
# Median Male Age                           float64
# Native American Population                float64
# Population                                float64
# Poverty                                   float64
# State                                      object
# Time                                      float64
# Time_Text                                  object
# Uni Lat                                   float64
# Uni Lng                                   float64
# University                                 object
# Uni CityState                              object
# White Population                          float64
# Physical_Campus                            object
# dtype: object

# %%
# Rejoin with the original dataframe to determine which university met the condition
minimum_distances = pd.merge(closest_location_pd, distance_values, on=["CityState", "Distance", "University"], how="left")

# %%
minimum_distances.count()
# Out:
# CityState                                 29119
# University                                29119
# Distance                                  29119
# Closest                                   29119
# Asian Population                          29119
# Black Population                          29119
# City                                      29119
# City Lat                                  29119
# City Lng                                  29119
# Distance_Text                             22731
# Education Associates                      29119
# Education Bachelors                       29119
# Education Doctorate                       29119
# Education GED                             29119
# Education High School                     29119
# Education Masters                         29119
# Education None                            29119
# Education Professional                    29119
# Employment Female Computer Engineering    29119
# Employment Labor Force                    29119
# Employment Male Computer Engineering      29119
# Employment Unemployed                     29119
# Google_URL                                22870
# Hispanic Population                       29119
# Household Income                          27437
# Income Per Capita                         28727
# Median Age                                28792
# Median Female Age                         28501
# Median Gross Rent                         23638
# Median Home Value                         27248
# Median Male Age                           28505
# Native American Population                29119
# Population                                29119
# Poverty                                   29119
# State                                     29119
# Time                                      22731
# Time_Text                                 22731
# Uni Lat                                   29119
# Uni Lng                                   29119
# Uni CityState                             29119
# White Population                          29119
# Physical_Campus                           29119
# dtype: int64

# %% [markdown]
# ### Run Test Cases

# %%
minimum_distances.head(200)
# Out:
#                        CityState University    Distance  Closest  \
# 0                 AARONSBURG, PA       PENN  140.339859     True
# 1                  ABBEVILLE, AL      GTECH  157.537626     True
# 2                  ABBEVILLE, GA      GTECH  138.382298     True
# 3                  ABBEVILLE, LA         UT  189.538012     True
# 4                  ABBEVILLE, MS       VAND  187.693841     True
# 5                  ABBEVILLE, SC      GTECH  116.574634     True
# 6                      ABBOT, ME        UNH  158.938804     True
# 7                 ABBOTSFORD, WI       MINN  144.634102     True
# 8                     ABBOTT, TX        SMU   68.416138     True
# 9                ABBOTTSTOWN, PA       PENN   94.939740     True
# 10                     ABELL, MD         GW   47.038451     True
# 11               ABERCROMBIE, ND       MINN  196.867734     True
# 12   ABERDEEN PROVING GROUND, MD       PENN   59.949207     True
# 13                  ABERDEEN, ID       UTAH  164.420299     True
# 14                  ABERDEEN, MD       PENN   62.037623     True
# 15                  ABERDEEN, MS       VAND  187.510012     True
# 16                  ABERDEEN, NC        UNC   58.466696     True
# 17                  ABERDEEN, OH        OSU   98.211065     True
# 18                  ABERDEEN, WA         UW   74.769063     True
# 19                      ABIE, NE         KU  196.496571     True
# 20                   ABILENE, KS         KU  139.847089     True
# 21                   ABILENE, TX        SMU  176.084188     True
# 22                  ABINGDON, IL         NU  165.912617     True
# 23                  ABINGDON, IL         NU  165.912617     True
# 24                  ABINGDON, MD         GW   56.273476     True
# 25                  ABINGDON, VA       UNCH  119.694981     True
# 26                  ABINGTON, MA       HARV   17.633752     True
# 27                  ABINGTON, PA       PENN   12.511147     True
# 28                    ABRAMS, WI        UWM  135.560418     True
# 29                   ABSECON, NJ        RUT   72.320292     True
# ..                           ...        ...         ...      ...
# 170                  ALBERTA, MN       MINN  142.755784     True
# 171                  ALBERTA, VA         UR   52.443214     True
# 172                  ALBERTA, VA         UR   52.443214     True
# 173                ALBERTSON, NC        UNC   88.478419     True
# 174                ALBERTSON, NY         CU   16.470192     True
# 175              ALBERTVILLE, AL      GTECH  110.135732     True
# 176              ALBERTVILLE, MN       MINN   28.131105     True
# 177                    ALBIA, IA         KU  163.196484     True
# 178                    ALBIN, WY         DU  127.520988     True
# 179                   ALBION, CA        UCB  119.308604     True
# 180                   ALBION, IA       MINN  196.548757     True
# 181                   ALBION, ID       UTAH  143.424794     True
# 182                   ALBION, IN      UMICH  107.828249     True
# 183                   ALBION, ME        UNH  120.404570     True
# 184                   ALBION, MI      UMICH   51.453033     True
# 185                   ALBION, OK        SMU  158.603486     True
# 186                   ALBION, PA       PENN  101.493710     True
# 187                   ALBION, RI       HARV   32.873263     True
# 188                   ALBORN, MN       MINN  139.860249     True
# 189                 ALBRIGHT, WV       PENN   63.228124     True
# 190           ALBRIGHTSVILLE, PA       PENN   75.358929     True
# 191                  ALBURGH, VT      UMASS  181.300720     True
# 192                ALBURNETT, IA        UWM  129.931840     True
# 193                 ALBURTIS, PA       PENN   43.471788     True
# 194                    ALCOA, TN       VAND  159.657849     True
# 195                   ALCOLU, SC      GTECH  129.106886     True
# 196                   ALCOVE, NY         CU  113.757649     True
# 197                    ALDEN, IA       MINN  170.527665     True
# 198                    ALDEN, MI      UMICH  193.557799     True
# 199                    ALDEN, MN       MINN   92.013373     True
#
# 25            26149.0            FALSE
# 26            14918.0            FALSE
# 27            12617.0            FALSE
# 28             2621.0            FALSE
# 29            26651.0            FALSE
# ..                ...              ...
# 170             241.0            FALSE
# 171             642.0            FALSE
# 172             642.0            FALSE
# 173            2188.0            FALSE
# 174            4839.0            FALSE
# 175           29837.0            FALSE
# 176            9214.0            FALSE
# 177            5673.0            FALSE
# 178             232.0            FALSE
# 179             838.0            FALSE
# 180             834.0            FALSE
# 181             491.0            FALSE
# 182            7658.0            FALSE
# 183            1737.0            FALSE
# 184           10621.0            FALSE
# 185              80.0            FALSE
# 186            5511.0            FALSE
# 187            1005.0            FALSE
# 188             448.0            FALSE
# 189            1779.0            FALSE
# 190            6665.0            FALSE
# 191            1673.0            FALSE
# 192            1024.0            FALSE
# 193            5151.0            FALSE
# 194            5844.0            FALSE
# 195             947.0            FALSE
# 196              17.0            FALSE
# 197            1496.0            FALSE
# 198            1099.0            FALSE
# 199            1465.0            FALSE
#
# [200 rows x 42 columns]

# %%
minimum_distances["CityState"].nunique()
# Out:
# 27238

# %%
minimum_distances[minimum_distances["Closest"] == False]
# Out:
# Empty DataFrame
# Columns: [CityState, University, Distance, Closest, Asian Population, Black Population, City, City Lat, City Lng, Distance_Text, Education Associates, Education Bachelors, Education Doctorate, Education GED, Education High School, Education Masters, Education None, Education Professional, Employment Female Computer Engineering, Employment Labor Force, Employment Male Computer Engineering, Employment Unemployed, Google_URL, Hispanic Population, Household Income, Income Per Capita, Median Age, Median Female Age, Median Gross Rent, Median Home Value, Median Male Age, Native American Population, Population, Poverty, State, Time, Time_Text, Uni Lat, Uni Lng, Uni CityState, White Population, Physical_Campus]
# Index: []
#
# [0 rows x 42 columns]

# %%
minimum_distances[(minimum_distances["CityState"] == "HOUSTON, TX")]
# Out:
#         CityState University  Distance  Closest  Asian Population  \
# 9660  HOUSTON, TX         UT  5.801359     True          230549.0
#
#       Black Population     City   City Lat   City Lng Distance_Text  \
# 9660          684416.0  HOUSTON  29.775734 -95.414548        8.9 mi
#
#            ...         Population   Poverty  State    Time  Time_Text  \
# 9660       ...          3061887.0  633609.0     TX  1147.0    19 mins
#
#         Uni Lat    Uni Lng  Uni CityState  White Population  Physical_Campus
# 9660  29.719949 -95.342233    HOUSTON, TX         1775897.0             TRUE
#
# [1 rows x 42 columns]

# %%
minimum_distances[(minimum_distances["CityState"] == "COLLEGE STATION, TX")]
# Out:
#                 CityState University   Distance  Closest  Asian Population  \
# 4243  COLLEGE STATION, TX         UT  82.671703     True            9757.0
#
#       Black Population             City   City Lat   City Lng Distance_Text  \
# 4243            7634.0  COLLEGE STATION  30.585239 -96.299284       97.0 mi
#
#            ...         Population  Poverty  State    Time       Time_Text  \
# 4243       ...           112074.0  32506.0     TX  5642.0  1 hour 34 mins
#
#         Uni Lat    Uni Lng  Uni CityState  White Population  Physical_Campus
# 4243  29.719949 -95.342233    HOUSTON, TX           89674.0            FALSE
#
# [1 rows x 42 columns]

# %%
minimum_distances[(minimum_distances["CityState"] == "BIRMINGHAM, AL")]
# Out:
#            CityState University    Distance  Closest  Asian Population  \
# 1783  BIRMINGHAM, AL      GTECH  139.819523     True           11585.0
#
#       Black Population        City   City Lat   City Lng Distance_Text  \
# 1783          217799.0  BIRMINGHAM  33.505136 -86.800174        152 mi
#
#            ...         Population  Poverty  State    Time        Time_Text  \
# 1783       ...           497450.0  92560.0     AL  8444.0  2 hours 21 mins
#
#         Uni Lat    Uni Lng  Uni CityState  White Population  Physical_Campus
# 1783  33.775618 -84.396285    ATLANTA, GA          251913.0            FALSE
#
# [1 rows x 42 columns]

# %%
minimum_distances[(minimum_distances["CityState"] == "NEW ORLEANS, LA")]
# Out:
#              CityState University    Distance  Closest  Asian Population  \
# 26757  NEW ORLEANS, LA         UT  317.843215     True           11942.0
#
#        Black Population         City   City Lat   City Lng Distance_Text  \
# 26757          229241.0  NEW ORLEANS  29.972238 -90.056357          None
#
#             ...         Population   Poverty  State  Time  Time_Text  \
# 26757       ...           415247.0  102960.0     LA   NaN       None
#
#          Uni Lat    Uni Lng  Uni CityState  White Population  Physical_Campus
# 26757  29.719949 -95.342233    HOUSTON, TX          160847.0            FALSE
#
# [1 rows x 42 columns]

# %%
minimum_distances[(minimum_distances["CityState"] == "MADISON, WI")]
# Out:
#          CityState University  Distance  Closest  Asian Population  \
# 12172  MADISON, WI        UWM  4.632362     True           21903.0
#
#        Black Population     City   City Lat   City Lng Distance_Text  \
# 12172           20773.0  MADISON  43.070701 -89.321318        8.3 mi
#
#             ...         Population  Poverty  State    Time  Time_Text  \
# 12172       ...           284782.0  50586.0     WI  1190.0    20 mins
#
#        Uni Lat  Uni Lng  Uni CityState  White Population  Physical_Campus
# 12172  43.0766 -89.4125    MADISON, WI          223464.0             TRUE
#
# [1 rows x 42 columns]

# %%
minimum_distances["CityState"].nunique()
# Out:
# 27238

# %%
minimum_distances[minimum_distances["CityState"] == "ZWOLLE, LA"]
# Out:
#         CityState University    Distance  Closest  Asian Population  \
# 22729  ZWOLLE, LA         UT  167.971661     True              36.0
#
#        Black Population    City   City Lat   City Lng Distance_Text  \
# 22729            1075.0  ZWOLLE  31.650584 -93.618811        203 mi
#
#             ...         Population  Poverty  State     Time        Time_Text  \
# 22729       ...             5721.0   1207.0     LA  12123.0  3 hours 22 mins
#
#          Uni Lat    Uni Lng  Uni CityState  White Population  Physical_Campus
# 22729  29.719949 -95.342233    HOUSTON, TX            3151.0            FALSE
#
# [1 rows x 42 columns]

# %% [markdown]
# ### Export Data

# %%
minimum_distances.to_csv("Outputs/03-Minimum_Distances_Matrix.csv")

# %%
minimum_distances.to_sql("Minimum_Distances", conn, if_exists="replace", index=False)
# Out:
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py:1345: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
# Check Tables in SQLite
cur = conn.cursor() 
res = cur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
for name in res:
    print(name[0])
# Out:
# City_Census
# FullDistances
# Minimum_Distances
# Rules_Added
# Zip_Census

# %% [markdown]
# ### Export to Cloud SQL

# %%
engine = create_engine('mysql+mysqldb://trilogy:DataRocks@35.227.28.228/mapping_data?unix_socket=/cloudsql/sql-projects:us-east1:opportunity-db')
conn = engine.connect()

minimum_distances.to_sql("Minimum_Distances", conn, if_exists="replace", index=False)
