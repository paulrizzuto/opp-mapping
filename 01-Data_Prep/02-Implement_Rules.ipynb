# %% [markdown]
# ## Implement Rules
# ---
# In this Jupyter notebook, we implement additive rules on the state and university levels, and negative rules on the university level.

# %% [markdown]
# ### Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time 
import sqlite3
import csv
from geopy.distance import vincenty
import glob
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ### Read the Additive Rules Files

# %%
#import border rules csv, clean up
border_rules = {}
csvpath = 'Raw/border-rules.csv'

with open(csvpath, newline= "") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    next(csvreader)

    for row in csvreader:
        state = row[0]
        border_rules[state] = row[1:]
        
for item in border_rules:
    border_rules[item] = [x for x in border_rules[item] if x]

#import university rules csv, clean up
uni_rules = {}
csvpath2 = 'Raw/uni-rules.csv'

with open(csvpath2, newline= "") as csvfile2:
    csvreader2 = csv.reader(csvfile2, delimiter=',')
    next(csvreader2)

    for row in csvreader2:
        uni = row[0]
        uni_rules[uni] = row[1:]

for item in uni_rules:
    uni_rules[item] = [x for x in uni_rules[item] if x]

# %%
border_rules
# Out:
# {'AK': ['AK'],
#  'AL': ['AL', 'FL', 'GA', 'MS', 'TN'],
#  'AR': ['AR', 'LA', 'MS', 'MO', 'OK', 'TN', 'TX'],
#  'AZ': ['AZ', 'CA', 'CO', 'NM', 'NV', 'UT'],
#  'CA': ['CA'],
#  'CO': ['CO', 'AZ', 'KS', 'NE', 'NM', 'OK', 'UT', 'WY', 'MT'],
#  'CT': ['CT', 'MA', 'NY', 'RI'],
#  'DC': ['DC', 'MD', 'VA'],
#  'DE': ['DE', 'MD'],
#  'FL': ['FL', 'AL', 'GA'],
#  'GA': ['GA', 'AL', 'FL', 'NC', 'SC', 'TN'],
#  'HI': ['HI'],
#  'IA': ['IA', 'IL', 'MN', 'MO', 'NE', 'SD', 'WI'],
#  'ID': ['ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY'],
#  'IL': ['IL', 'IN', 'IA', 'MI', 'KY', 'MO', 'WI'],
#  'IN': ['IN', 'IL', 'KY', 'MI', 'OH'],
#  'KS': ['KS', 'CO', 'MO', 'NE', 'OK'],
#  'KY': ['KY', 'IL', 'IN', 'MO', 'OH', 'TN', 'VA', 'WV'],
#  'LA': ['LA', 'AR', 'MS', 'TX'],
#  'MA': ['MA', 'CT', 'NH', 'RI', 'VT'],
#  'MD': ['MD', 'DE', 'VA', 'WV'],
#  'ME': ['ME', 'NH'],
#  'MI': ['MI', 'IL', 'IN', 'OH', 'WI'],
#  'MN': ['MN', 'IA', 'ND', 'SD', 'WI', 'MT'],
#  'MO': ['MO', 'AR', 'IL', 'IA', 'KS', 'KY', 'NE', 'OK', 'TN'],
#  'MS': ['MS', 'AL', 'AR', 'LA', 'TN'],
#  'MT': ['MT', 'ID', 'ND', 'SD', 'WY'],
#  'NC': ['NC', 'GA', 'SC', 'TN', 'VA'],
#  'ND': ['ND', 'MN', 'MT', 'SD'],
#  'NE': ['NE', 'CO', 'IA', 'KS', 'MO', 'SD', 'WY'],
#  'NH': ['NH', 'ME', 'MA', 'VT'],
#  'NJ': ['NJ', 'DE', 'NY'],
#  'NM': ['NM', 'AZ', 'CO', 'OK', 'TX', 'UT'],
#  'NV': ['NV', 'AZ', 'CA', 'ID', 'OR', 'UT'],
#  'NY': ['NY', 'CT', 'MA', 'VT'],
#  'OH': ['OH', 'IN', 'KY', 'MI', 'WV'],
#  'OK': ['OK', 'AR', 'CO', 'KS', 'MO', 'NM', 'TX'],
#  'OR': ['OR', 'CA', 'ID', 'NV', 'WA'],
#  'PA': ['PA', 'DE', 'MD', 'NY', 'OH', 'WV'],
#  'RI': ['RI', 'CT', 'MA'],
#  'SC': ['SC', 'GA', 'NC'],
#  'SD': ['SD', 'IA', 'MN', 'MT', 'NE', 'ND', 'WY'],
#  'TN': ['TN', 'AL', 'AR', 'GA', 'KY', 'MS', 'MO', 'NC', 'VA'],
#  'TX': ['TX', 'AR', 'LA', 'NM', 'OK'],
#  'UT': ['UT', 'AZ', 'CO', 'ID', 'NV', 'NM', 'WY', 'MT'],
#  'VA': ['VA', 'KY', 'MD', 'OH', 'VA'],
#  'VT': ['VT', 'MA', 'NH', 'NY'],
#  'WA': ['WA', 'ID', 'OR', 'MT'],
#  'WI': ['WI', 'IL', 'IA', 'MI', 'MN'],
#  'WV': ['WV', 'KY', 'MD', 'OH', 'VA'],
#  'WY': ['WY', 'CO', 'ID', 'MT', 'NE', 'SD', 'UT']}

# %%
uni_rules
# Out:
# {'CU': [],
#  'CWR': ['NY'],
#  'DU': [],
#  'GTECH': [],
#  'GW': [],
#  'HARV': [],
#  'KU': ['IA'],
#  'MIAMI': [],
#  'MINN': [],
#  'NU': [],
#  'OSU': [],
#  'PENN': [],
#  'RUT': [],
#  'SMU': [],
#  'UA': [],
#  'UCB': [],
#  'UCD': [],
#  'UCF': [],
#  'UCI': [],
#  'UCLA': [],
#  'UCSD': [],
#  'UMASS': [],
#  'UMICH': [],
#  'UNC': [],
#  'UNCH': [],
#  'UNH': [],
#  'UP': [],
#  'UR': [],
#  'UT': [],
#  'UTAH': [],
#  'UTSA': [],
#  'UW': [],
#  'UWM': [],
#  'VAND': [],
#  'WASHU': []}

# %% [markdown]
# ### Read the List of Physical Locations

# %%
#import physical location data for each university to check (make sure uni_rules.csv is updated according to this list)
physical_locations = pd.read_excel("Raw/Physical_Campuses_geo.xlsx")
physical_locations.count()
# Out:
# University             44
# CityState              44
# Physical_Campus        44
# Current_Prospective    44
# State                  44
# Uni_lat                44
# Uni_lng                44
# dtype: int64

# %%
physical_locations
# Out:
#    University           CityState  Physical_Campus Current_Prospective State  \
# 0       UMASS         AMHERST, MA             True             Current    MA
# 1       GTECH         ATLANTA, GA             True             Current    GA
# 2          UT          AUSTIN, TX             True             Current    TX
# 3         UCB        BERKELEY, CA             True             Current    CA
# 4        HARV          BOSTON, MA             True         Prospective    MA
# 5         UNC     CHAPEL HILL, NC             True             Current    NC
# 6        UNCH       CHARLOTTE, NC             True             Current    NC
# 7          NU         CHICAGO, IL             True             Current    IL
# 8         CWR       CLEVELAND, OH             True             Current    OH
# 9         OSU        COLUMBUS, OH             True         Prospective    OH
# 10        SMU          DALLAS, TX             True             Current    TX
# 11        UCD           DAVIS, CA             True             Current    CA
# 12         DU          DENVER, CO             True             Current    CO
# 13      UMICH         DETROIT, MI             True         Prospective    MI
# 14        UNH          DURHAM, NH             True             Current    NH
# 15         NU        EVANSTON, IL             True             Current    IL
# 16         UT         HOUSTON, TX             True             Current    TX
# 17        UCI          IRVINE, CA             True             Current    CA
# 18        RUT     JERSEY CITY, NJ             True             Current    NJ
# 19         KU     KANSAS CITY, KS             True             Current    KS
# 20       UCSD        LA JOLLA, CA             True             Current    CA
# 21       UCLA     LOS ANGELES, CA             True             Current    CA
# 22      MIAMI           MIAMI, FL             True             Current    FL
# 23       MINN     MINNEAPOLIS, MN             True             Current    MN
# 24       VAND       NASHVILLE, TN             True         Prospective    TN
# 25         CU        NEW YORK, NY             True         Prospective    NY
# 26        UCF         ORLANDO, FL             True             Current    FL
# 27       PENN    PHILADELPHIA, PA             True             Current    PA
# 28         UA         PHOENIX, AZ             True             Current    AZ
# 29       PENN      PITTSBURGH, PA             True         Prospective    PA
# 30         UP        PORTLAND, OR             True         Prospective    OR
# 31         UR        RICHMOND, VA             True             Current    VA
# 32        UCD      SACRAMENTO, CA             True             Current    CA
# 33      WASHU     SAINT LOUIS, MO             True         Prospective    MO
# 34       UTAH  SALT LAKE CITY, UT             True             Current    UT
# 35       UTSA     SAN ANTONIO, TX             True             Current    TX
# 36        UCB   SAN FRANCISCO, CA             True             Current    CA
# 37      GTECH        SAVANNAH, GA             True             Current    GA
# 38         UW         SEATTLE, WA             True         Prospective    WA
# 39        RUT        SOMERSET, NJ             True             Current    NJ
# 40        UCF           TAMPA, FL             True         Prospective    FL
# 41         UA          TUCSON, AZ             True             Current    AZ
# 42         GW      WASHINGTON, DC             True             Current    DC
# 43        UWM         MADISON, WI             True         Prospective    WI
#
#       Uni_lat     Uni_lng
# 0   42.391157  -72.526712
# 1   33.775618  -84.396285
# 2   30.284918  -97.734057
# 3   37.871899 -122.258540
# 4   42.350500  -71.105399
# 5   35.904912  -79.046913
# 6   35.307093  -80.735164
# 7   42.056459  -87.675267
# 8   41.504341  -81.608384
# 9   40.014190  -83.030914
# 10  32.841218  -96.784518
# 11  38.538232 -121.761713
# 12  39.676617 -104.961896
# 13  42.280800  -83.743000
# 14  43.138948  -70.937025
# 15  42.056459  -87.675267
# 16  29.719949  -95.342233
# 17  33.640495 -117.844296
# 18  40.500819  -74.447399
# 19  39.114100  -94.627500
# 20  32.880060 -117.234014
# 21  34.068921 -118.445181
# 22  25.761700  -80.191800
# 23  44.975354  -93.233074
# 24  36.144703  -86.802655
# 25  40.807536  -73.962573
# 26  28.602427  -81.200060
# 27  39.952219  -75.193214
# 28  33.448400 -112.074000
# 29  40.440600  -79.995900
# 30  45.523100 -122.676500
# 31  37.548987  -77.453429
# 32  38.581600 -121.494400
# 33  38.648789  -90.310796
# 34  40.764937 -111.842102
# 35  29.424100  -98.493600
# 36  37.776647 -122.450683
# 37  32.083500  -81.099800
# 38  47.655335 -122.303520
# 39  40.497600  -74.488500
# 40  28.058703  -82.413854
# 41  32.231885 -110.950109
# 42  38.899715  -77.048599
# 43  43.076600  -89.412500

# %% [markdown]
# ### Read the Full List of Cities

# %%
#import census data for each CityState
conn = sqlite3.connect("Opportunity_Map.db")
full_cities = pd.read_sql("select * from City_Census", conn)

# %% [markdown]
# ### Run Additive Rules

# %%
#create dataframe by checking universities using border rules
border_rules_check = pd.DataFrame(columns=['City', 'State', 'City Lat', 'City Lng',
                                      'University', 'Uni Lat', 'Uni Lng', 'Distance'])

counter = 0
for index, row in physical_locations.iterrows():
     print("Checking " + row["University"])
     state_pull = row["State"]
     uni_lat = row["Uni_lat"]
     uni_lng = row["Uni_lng"]
     uni_name = row["University"]
     uni_loc = row["CityState"]
     for item in border_rules[state_pull]:
         if item is not "":
             #check against the city/state dataframe, create new dataframe of values, add values for city/state and lat/lng
             for index, row in full_cities.iterrows():
                 if row["state"] == item:
                     city_name = row["city"]
                     state_name = row["state"]
                     city_lat = row["lat"]
                     city_lng = row["lng"]
                     city_state = row["CityState"]
                    
                     p1 = (uni_lat, uni_lng)
                     p2 = (city_lat, city_lng)
                     mi_distance = vincenty(p1, p2).miles
                     
                     border_rules_check.set_value(counter, "Distance", mi_distance)
                     border_rules_check.set_value(counter, "City", city_name)
                     border_rules_check.set_value(counter, "State", state_name)
                     border_rules_check.set_value(counter, "City Lat", city_lat)
                     border_rules_check.set_value(counter, "City Lng", city_lng)
                     border_rules_check.set_value(counter, "University", uni_name)
                     border_rules_check.set_value(counter, "Uni CityState", uni_loc)
                     border_rules_check.set_value(counter, "Uni Lat", uni_lat)
                     border_rules_check.set_value(counter, "Uni Lng", uni_lng)
                     border_rules_check.set_value(counter, "CityState", city_state)
                     counter = counter + 1
                 else:
                     continue

border_rules_check.head()
# Out:
# Checking UMASS
# Checking GTECH
# Checking UT
# Checking UCB
# Checking HARV
# Checking UNC
# Checking UNCH
# Checking NU
# Checking CWR
# Checking OSU
# Checking SMU
# Checking UCD
# Checking DU
# Checking UMICH
# Checking UNH
# Checking NU
# Checking UT
# Checking UCI
# Checking RUT
# Checking KU
# Checking UCSD
# Checking UCLA
# Checking MIAMI
# Checking MINN
# Checking VAND
# Checking CU
# Checking UCF
# Checking PENN
# Checking UA
# Checking PENN
# Checking UP
# Checking UR
# Checking UCD
# Checking WASHU
# Checking UTAH
# Checking UTSA
# Checking UCB
# Checking GTECH
# Checking UW
# Checking RUT
# Checking UCF
# Checking UA
# Checking GW
# Checking UWM
#        City State City Lat City Lng University  Uni Lat  Uni Lng Distance  \
# 0  ABINGTON    MA    42.12 -70.9572      UMASS  42.3912 -72.5267   82.622
# 1     ACTON    MA   42.484 -71.4385      UMASS  42.3912 -72.5267  56.0042
# 2  ACUSHNET    MA  41.7182 -70.9012      UMASS  42.3912 -72.5267   95.645
# 3     ADAMS    MA  42.6238 -73.1167      UMASS  42.3912 -72.5267   34.144
# 4    AGAWAM    MA  42.0624 -72.6258      UMASS  42.3912 -72.5267  23.2549
#
#   Uni CityState     CityState
# 0   AMHERST, MA  ABINGTON, MA
# 1   AMHERST, MA     ACTON, MA
# 2   AMHERST, MA  ACUSHNET, MA
# 3   AMHERST, MA     ADAMS, MA
# 4   AMHERST, MA    AGAWAM, MA

# %%
border_rules_check.head()
# Out:
#        City State City Lat City Lng University  Uni Lat  Uni Lng Distance  \
# 0  ABINGTON    MA    42.12 -70.9572      UMASS  42.3912 -72.5267   82.622
# 1     ACTON    MA   42.484 -71.4385      UMASS  42.3912 -72.5267  56.0042
# 2  ACUSHNET    MA  41.7182 -70.9012      UMASS  42.3912 -72.5267   95.645
# 3     ADAMS    MA  42.6238 -73.1167      UMASS  42.3912 -72.5267   34.144
# 4    AGAWAM    MA  42.0624 -72.6258      UMASS  42.3912 -72.5267  23.2549
#
#   Uni CityState     CityState
# 0   AMHERST, MA  ABINGTON, MA
# 1   AMHERST, MA     ACTON, MA
# 2   AMHERST, MA  ACUSHNET, MA
# 3   AMHERST, MA     ADAMS, MA
# 4   AMHERST, MA    AGAWAM, MA

# %%
#create additional dataframe by checking universities using university rules
uni_rules_check = pd.DataFrame(columns=['City', 'State', 'City Lat', 'City Lng',
                                      'University', 'Uni Lat', 'Uni Lng', 'Distance', 'Priority'])

counter = 0
for index, row in physical_locations.iterrows():
    print("Checking " + row["University"])
    uni_pull = row["University"]
    uni_lat = row["Uni_lat"]
    uni_lng = row["Uni_lng"]
    uni_name = row["University"]
    uni_loc = row["CityState"]
    for item in uni_rules[uni_pull]:
        if item is not "":
            #check against the city/state dataframe, create new dataframe of values, add values for city/state and lat/lng
            for index, row in full_cities.iterrows():
                if row["state"] == item or row["CityState"] == item:
                    city_name = row["city"]
                    state_name = row["state"]
                    city_lat = row["lat"]
                    city_lng = row["lng"]
                    city_state = row["CityState"]
                    
                    p1 = (uni_lat, uni_lng)
                    p2 = (city_lat, city_lng)
                    mi_distance = vincenty(p1, p2).miles

                    uni_rules_check.set_value(counter, "Distance", mi_distance)
                    uni_rules_check.set_value(counter, "City", city_name)
                    uni_rules_check.set_value(counter, "State", state_name)
                    uni_rules_check.set_value(counter, "City Lat", city_lat)
                    uni_rules_check.set_value(counter, "City Lng", city_lng)
                    uni_rules_check.set_value(counter, "University", uni_name)
                    uni_rules_check.set_value(counter, "Uni CityState", uni_loc)
                    uni_rules_check.set_value(counter, "Uni Lat", uni_lat)
                    uni_rules_check.set_value(counter, "Uni Lng", uni_lng)
                    uni_rules_check.set_value(counter, "CityState", city_state)
                    uni_rules_check.set_value(counter, "Priority", True)
                    counter = counter + 1

                else:
                    continue

uni_rules_check.head()
# Out:
# Checking UMASS
# Checking GTECH
# Checking UT
# Checking UCB
# Checking HARV
# Checking UNC
# Checking UNCH
# Checking NU
# Checking CWR
# Checking OSU
# Checking SMU
# Checking UCD
# Checking DU
# Checking UMICH
# Checking UNH
# Checking NU
# Checking UT
# Checking UCI
# Checking RUT
# Checking KU
# Checking UCSD
# Checking UCLA
# Checking MIAMI
# Checking MINN
# Checking VAND
# Checking CU
# Checking UCF
# Checking PENN
# Checking UA
# Checking PENN
# Checking UP
# Checking UR
# Checking UCD
# Checking WASHU
# Checking UTAH
# Checking UTSA
# Checking UCB
# Checking GTECH
# Checking UW
# Checking RUT
# Checking UCF
# Checking UA
# Checking GW
# Checking UWM
#            City State City Lat City Lng University  Uni Lat  Uni Lng Distance  \
# 0        ACCORD    NY   41.819 -74.2361        CWR  41.5043 -81.6084  382.037
# 1          ACRA    NY  42.3179  -74.086        CWR  41.5043 -81.6084  391.709
# 2  ADAMS CENTER    NY  43.8726 -76.0147        CWR  41.5043 -81.6084  328.309
# 3         ADAMS    NY  43.8074 -76.0504        CWR  41.5043 -81.6084  324.643
# 4       ADDISON    NY  42.1041  -77.293        CWR  41.5043 -81.6084  226.627
#
#   Priority  Uni CityState         CityState
# 0     True  CLEVELAND, OH        ACCORD, NY
# 1     True  CLEVELAND, OH          ACRA, NY
# 2     True  CLEVELAND, OH  ADAMS CENTER, NY
# 3     True  CLEVELAND, OH         ADAMS, NY
# 4     True  CLEVELAND, OH       ADDISON, NY

# %%
#university rules incorporated at front end, would then concatenate these frames and continue with rest of the script
frames = [border_rules_check, uni_rules_check]
additive_rules_df = pd.concat(frames, join='outer')

# %%
additive_rules_df.reset_index(inplace=True)

# %%
additive_rules_df.to_csv("full_additive_rules.csv")

# %%
additive_rules_df.head()
# Out:
#    index      City City Lat City Lng     CityState Distance Priority State  \
# 0      0  ABINGTON    42.12 -70.9572  ABINGTON, MA   82.622      NaN    MA
# 1      1     ACTON   42.484 -71.4385     ACTON, MA  56.0042      NaN    MA
# 2      2  ACUSHNET  41.7182 -70.9012  ACUSHNET, MA   95.645      NaN    MA
# 3      3     ADAMS  42.6238 -73.1167     ADAMS, MA   34.144      NaN    MA
# 4      4    AGAWAM  42.0624 -72.6258    AGAWAM, MA  23.2549      NaN    MA
#
#   Uni CityState  Uni Lat  Uni Lng University
# 0   AMHERST, MA  42.3912 -72.5267      UMASS
# 1   AMHERST, MA  42.3912 -72.5267      UMASS
# 2   AMHERST, MA  42.3912 -72.5267      UMASS
# 3   AMHERST, MA  42.3912 -72.5267      UMASS
# 4   AMHERST, MA  42.3912 -72.5267      UMASS

# %% [markdown]
# ### Read the Negative Rules Files

# %%
#incorporate negative rules on full frame
#import university rules csv, clean up
negative_rules = {}
csvpath = 'Raw/negative-rules.csv'

with open(csvpath, newline= "") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    next(csvreader)

    for row in csvreader:
        uni = row[0]
        negative_rules[uni] = row[1:]

for item in negative_rules:
    negative_rules[item] = [x for x in negative_rules[item] if x]

# %%
negative_rules
# Out:
# {'CU': [],
#  'CWR': [],
#  'DU': [],
#  'GTECH': ['TN', 'FL'],
#  'GW': [],
#  'HARV': [],
#  'KU': [],
#  'MIAMI': [],
#  'MINN': [],
#  'NU': [],
#  'OSU': [],
#  'PENN': [],
#  'RUT': [],
#  'SMU': [],
#  'UA': [],
#  'UCB': [],
#  'UCD': [],
#  'UCF': [],
#  'UCI': [],
#  'UCLA': [],
#  'UCSD': [],
#  'UMASS': [],
#  'UMICH': [],
#  'UNC': [],
#  'UNCH': [],
#  'UNH': [],
#  'UP': ['NJ'],
#  'UR': [],
#  'UT': [],
#  'UTAH': [],
#  'UTSA': [],
#  'UW': [],
#  'VAND': [],
#  'WASHU': ['IL']}

# %%
for index, row in additive_rules_df.iterrows():
    if row["University"] in negative_rules:
        for item in negative_rules[row["University"]]:
            if (row["State"] == item) or (row["CityState"] == item):
                additive_rules_df.drop(index, inplace=True)

# %%
test = additive_rules_df[additive_rules_df["University"] == "GTECH"]

# %%
test[test["State"] == "FL"]
# Out:
# Empty DataFrame
# Columns: [index, City, City Lat, City Lng, CityState, Distance, Priority, State, Uni CityState, Uni Lat, Uni Lng, University]
# Index: []

# %%
additive_rules_df = additive_rules_df[['City', 'City Lat', 'City Lng', 'CityState', 'Distance',
       'Priority', 'State', 'Uni CityState', 'Uni Lat', 'Uni Lng',
       'University']]

# %%
additive_rules_df.to_csv("with_negative_rules.csv")

# %% [markdown]
# ### Distance Check

# %%
additive_rules_df = additive_rules_df[additive_rules_df["Distance"] <= 200]

# %%
additive_rules_df.head()
# Out:
#        City City Lat City Lng     CityState Distance Priority State  \
# 0  ABINGTON    42.12 -70.9572  ABINGTON, MA   82.622      NaN    MA
# 1     ACTON   42.484 -71.4385     ACTON, MA  56.0042      NaN    MA
# 2  ACUSHNET  41.7182 -70.9012  ACUSHNET, MA   95.645      NaN    MA
# 3     ADAMS  42.6238 -73.1167     ADAMS, MA   34.144      NaN    MA
# 4    AGAWAM  42.0624 -72.6258    AGAWAM, MA  23.2549      NaN    MA
#
#   Uni CityState  Uni Lat  Uni Lng University
# 0   AMHERST, MA  42.3912 -72.5267      UMASS
# 1   AMHERST, MA  42.3912 -72.5267      UMASS
# 2   AMHERST, MA  42.3912 -72.5267      UMASS
# 3   AMHERST, MA  42.3912 -72.5267      UMASS
# 4   AMHERST, MA  42.3912 -72.5267      UMASS

# %% [markdown]
# ### Export

# %%
#the following selection of CityStates is within range for a google distance check

# %%
final_rules = additive_rules_df

final_rules.to_csv("testing_distance.csv")

# %%
final_rules.to_sql("Rules_Added", conn, if_exists="replace", index=False)
# Out:
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py:1345: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
# Check Tables in SQLite
cur = conn.cursor() 
res = cur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
for name in res:
    print(name[0])
# Out:
# City_Census
# Rules_Added
# Zip_Census

# %%
final_rules[final_rules["CityState"] == "SHINGLEHOUSE, PA"]
# Out:
#                City City Lat City Lng         CityState Distance Priority  \
# 84444  SHINGLEHOUSE  41.9472 -78.1445  SHINGLEHOUSE, PA  141.848      NaN
#
#       State   Uni CityState  Uni Lat  Uni Lng University
# 84444    PA  PITTSBURGH, PA  40.4406 -79.9959       PENN

# %% [markdown]
# ### Export to Cloud SQL

# %%
engine = create_engine('mysql+mysqldb://trilogy:DataRocks@35.227.28.228/mapping_data?unix_socket=/cloudsql/sql-projects:us-east1:opportunity-db')
conn = engine.connect()

final_rules.to_sql("Rules_Added", conn, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1121             wait = use_overflow and self._overflow >= self._max_overflow
# -> 1122             return self._pool.get(wait, self._timeout)
#    1123         except sqla_queue.Empty:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/queue.py in get(self, block, timeout)
#     144                 if self._empty():
# --> 145                     raise Empty
#     146             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     915                                 (self.host, self.port), self.connect_timeout,
# --> 916                                 **kwargs)
#     917                             break
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     721     if err is not None:
# --> 722         raise err
#     723     else:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2146         try:
# -> 2147             return fn()
#    2148         except dialect.dbapi.Error as e:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     327         """
# --> 328         return _ConnectionFairy._checkout(self)
#     329
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     765         if not fairy:
# --> 766             fairy = _ConnectionRecord.checkout(pool)
#     767
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     515     def checkout(cls, pool):
# --> 516         rec = pool._do_get()
#     517         try:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1137                     with util.safe_reraise():
# -> 1138                         self._dec_overflow()
#    1139             else:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1134                 try:
# -> 1135                     return self._create_connection()
#    1136                 except:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     332
# --> 333         return _ConnectionRecord(self)
#     334
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     460         if connect:
# --> 461             self.__connect(first_connect_check=True)
#     462         self.finalize_callback = deque()
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     650             self.starttime = time.time()
# --> 651             connection = pool._invoke_creator(self)
#     652             pool.logger.debug("Created new connection %r", connection)
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     392     def connect(self, *cargs, **cparams):
# --> 393         return self.dbapi.connect(*cargs, **cparams)
#     394
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      89     from .connections import Connection
# ---> 90     return Connection(*args, **kwargs)
#      91
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, no_delay, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address)
#     705         else:
# --> 706             self.connect()
#     707
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     962                 if DEBUG: print(exc.traceback)
# --> 963                 raise exc
#     964
#
# OperationalError: (2003, "Can't connect to MySQL server on '35.227.28.228' (timed out)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-29-ece086f4acad> in <module>()
#       1 engine = create_engine('mysql+mysqldb://trilogy:DataRocks@35.227.28.228/mapping_data?unix_socket=/cloudsql/sql-projects:us-east1:opportunity-db')
# ----> 2 conn = engine.connect()
#       3
#       4 final_rules.to_sql("Rules_Added", conn, if_exists="replace", index=False)
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2089         """
#    2090
# -> 2091         return self._connection_cls(self, **kwargs)
#    2092
#    2093     def contextual_connect(self, close_with_result=False, **kwargs):
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      88         else:
#      89             self.__connection = connection \
# ---> 90                 if connection is not None else engine.raw_connection()
#      91             self.__transaction = None
#      92             self.__savepoint_seq = 0
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2175         """
#    2176         return self._wrap_pool_connect(
# -> 2177             self.pool.unique_connection, _connection)
#    2178
#    2179
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2149             if connection is None:
#    2150                 Connection._handle_dbapi_exception_noconnection(
# -> 2151                     e, dialect, self)
#    2152             else:
#    2153                 util.reraise(*sys.exc_info())
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1463             util.raise_from_cause(
#    1464                 sqlalchemy_exception,
# -> 1465                 exc_info
#    1466             )
#    1467         else:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2145         dialect = self.dialect
#    2146         try:
# -> 2147             return fn()
#    2148         except dialect.dbapi.Error as e:
#    2149             if connection is None:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     326
#     327         """
# --> 328         return _ConnectionFairy._checkout(self)
#     329
#     330     def _create_connection(self):
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     764     def _checkout(cls, pool, threadconns=None, fairy=None):
#     765         if not fairy:
# --> 766             fairy = _ConnectionRecord.checkout(pool)
#     767
#     768             fairy._pool = pool
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     514     @classmethod
#     515     def checkout(cls, pool):
# --> 516         rec = pool._do_get()
#     517         try:
#     518             dbapi_connection = rec.get_connection()
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1136                 except:
#    1137                     with util.safe_reraise():
# -> 1138                         self._dec_overflow()
#    1139             else:
#    1140                 return self._do_get()
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1133             if self._inc_overflow():
#    1134                 try:
# -> 1135                     return self._create_connection()
#    1136                 except:
#    1137                     with util.safe_reraise():
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     331         """Called by subclasses to create a new ConnectionRecord."""
#     332
# --> 333         return _ConnectionRecord(self)
#     334
#     335     def _invalidate(self, connection, exception=None):
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     459         self.__pool = pool
#     460         if connect:
# --> 461             self.__connect(first_connect_check=True)
#     462         self.finalize_callback = deque()
#     463
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     649         try:
#     650             self.starttime = time.time()
# --> 651             connection = pool._invoke_creator(self)
#     652             pool.logger.debug("Created new connection %r", connection)
#     653             self.connection = connection
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     103                         if connection is not None:
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#     107             creator = pop_kwarg('creator', connect)
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     391
#     392     def connect(self, *cargs, **cparams):
# --> 393         return self.dbapi.connect(*cargs, **cparams)
#     394
#     395     def create_connect_args(self, url):
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      88     """
#      89     from .connections import Connection
# ---> 90     return Connection(*args, **kwargs)
#      91
#      92 from . import connections as _orig_conn
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, no_delay, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address)
#     704             self._sock = None
#     705         else:
# --> 706             self.connect()
#     707
#     708     def _create_ssl_ctx(self, sslp):
#
# /Users/paul/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     961                 exc.traceback = traceback.format_exc()
#     962                 if DEBUG: print(exc.traceback)
# --> 963                 raise exc
#     964
#     965             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '35.227.28.228' (timed out)")
